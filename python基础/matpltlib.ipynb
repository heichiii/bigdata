# %% [markdown]
# # matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,20,200)

# %%
y = np.sin(x)

# %%
plt.scatter(x,y)
plt.axhline(y=0.75, ls='--',c='r')
plt.text(3.5,0,'sin(x)',weight = 'bold', c='r')
# Out:
# Text(3.5, 0, 'sin(x)')

# %%
import matplotlib.pyplot as plt
import numpy as np
rng = np.random.RandomState(10)

# %%
k = rng.rand(100)
f = rng.rand(100)

# %%
plt.scatter(k, f, c=rng.rand(100),sizes=1000*rng.rand(100),alpha=0.3 ,cmap = 'viridis')

# %%
categ = ['beer','wine','sprit','alcoh']

# %%
va = [10,20,50,35]

# %%
plt.bar(categ,va,color = 'black',width=0.5, label='bar')
plt.xlabel('jiu')
plt.ylabel('sail')
plt.title('this is a title')
# Out:
# Text(0.5, 1.0, 'this is a title')

# %%
x = np.random.randn(100)

# %%
plt.hist(x)
# Out:
# (array([ 2.,  2.,  5.,  6., 19., 16., 20., 20.,  6.,  4.]),
#  array([-2.98817982, -2.47025369, -1.95232757, -1.43440144, -0.91647532,
#         -0.39854919,  0.11937693,  0.63730306,  1.15522918,  1.6731553 ,
#          2.19108143]),
#  <BarContainer object of 10 artists>)

# %%
list = [1,2,3,4,2,3,1]
plt.hist(list)
# Out:
# (array([2., 0., 0., 2., 0., 0., 2., 0., 0., 1.]),
#  array([1. , 1.3, 1.6, 1.9, 2.2, 2.5, 2.8, 3.1, 3.4, 3.7, 4. ]),
#  <BarContainer object of 10 artists>)

# %%
x = np.random.normal(0,0.8,1000)
y = np.random.normal(-3,1,1000)
z = np.random.normal(3,2.,1000)

# %%
kwargs = dict(alpha=0.3, bins=40,density=True)

# %%
plt.hist(x, **kwargs)
plt.hist(y,**kwargs)
plt.hist(z,**kwargs)
# Out:
# (array([0.00615132, 0.        , 0.        , 0.        , 0.        ,
#         0.01537831, 0.00615132, 0.01230265, 0.02152964, 0.0246053 ,
#         0.01845397, 0.03690795, 0.02768096, 0.08304289, 0.06766457,
#         0.14148047, 0.11687517, 0.13225348, 0.1722371 , 0.18453975,
#         0.20914505, 0.21837203, 0.20299372, 0.18146408, 0.20914505,
#         0.17531276, 0.15685878, 0.1230265 , 0.09534554, 0.08919421,
#         0.08611855, 0.07689156, 0.06151325, 0.0492106 , 0.02152964,
#         0.01230265, 0.01230265, 0.01845397, 0.00307566, 0.00615132]),
#  array([-4.24565471, -3.9205215 , -3.59538829, -3.27025507, -2.94512186,
#         -2.61998865, -2.29485544, -1.96972223, -1.64458902, -1.31945581,
#         -0.9943226 , -0.66918939, -0.34405618, -0.01892297,  0.30621024,
#          0.63134345,  0.95647666,  1.28160987,  1.60674308,  1.93187629,
#          2.2570095 ,  2.58214271,  2.90727593,  3.23240914,  3.55754235,
#          3.88267556,  4.20780877,  4.53294198,  4.85807519,  5.1832084 ,
#          5.50834161,  5.83347482,  6.15860803,  6.48374124,  6.80887445,
#          7.13400766,  7.45914087,  7.78427408,  8.10940729,  8.4345405 ,
#          8.75967371]),
#  <BarContainer object of 40 artists>)

# %%
x = np.random.rand(1000)

# %%
y = np.random.rand(1000)

# %%
plt.hist2d(x,y,bins=[10,20])
plt.xlabel('x-ax')
plt.ylabel('y-ax')
plt.colorbar()

# %%
x = [1,2,3,4,5,6]
y = [2,3,4,5,6,7]
plt.bar(x,y)
plt.title('barbar')
plt.xlabel('x-label')
plt.ylabel('y-label')
# plt.show()

# %%
x = [1,2,3,4,5,6]
y = ['dog','cat','elephant','mouse','human','snake']
plt.pie(x,labels=y, autopct='%1.1f%%')
plt.title('pie')
plt.xlabel('x-label')
plt.ylabel('y-label')
# Out:
# Text(0, 0.5, 'y-label')

# %%
x = [1,2,3,4,4,5]
y = [1,2,3,4,5,6]
plt.subplot(2,2,1)
plt.bar(x,y)
plt.title('bar')

x = [1,2,3,4,4,5]
y = [1,2,3,4,5,6]
plt.subplot(2,2,2)
plt.plot(x,y,color = 'r')
plt.title('line')

x = [1,2,3,4,4,5]
y = [1,2,3,4,5,6]
plt.subplot(2,2,3)
plt.pie(x,labels=y,autopct='%1.1f%%')
plt.title('pie')

x = [1,2,3,4,4,5,6,7,8,9]
y = [1,2,3,4,5,6,3,2,5,2]
plt.subplot(2,2,4)
plt.scatter(x,y,color = 'black')
plt.title('scatter')
# Out:
# Text(0.5, 1.0, 'scatter')

# %%
x = np.random.randn(100)
y = np.random.randn(100)
z = np.random.randn(100)

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x,y,z,c='r',marker='o')
ax.set_xlabel('x-label')
ax.set_ylabel('y-label')
ax.set_zlabel('z-label')
plt.t
# Out:
# Text(0.5, 0, 'z-label')

# %%
ax.scatter(x,y,z)

# %%
plt.show()
